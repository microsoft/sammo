# %%
# Load from parent directory if not installed
import importlib
import os

if not importlib.util.find_spec("sammo"):
    import sys

    sys.path.append("../")
os.environ["CACHE_FILE"] = "cache/chaining_prompts.tsv"

# %% [markdown]
# # Symbolic Prompt Programs
#
# At the heart of SAMMO are symbolic prompt programs. If you are familiar with JavaScript, you can think of these of a DOM tree representation of prompts. If you aren't, no problem -- we'll start from the basics.

# %%
# %load -r 3:25 _init.py
import pathlib
import sammo
from sammo.runners import OpenAIChat
from sammo.base import Template, EvaluationScore
from sammo.extractors import ExtractRegex
from sammo.data import DataTable
import json
import requests
import os

if not 'OPENAI_API_KEY' in os.environ:
    raise ValueError("Please set the environment variable 'OPENAI_API_KEY'.")

_ = sammo.setup_logger("WARNING")  # we're only interested in warnings for now

runner = OpenAIChat(
    model_id="gpt-3.5-turbo",
    api_config={"api_key": os.environ['OPENAI_API_KEY']},
    cache=os.getenv("CACHE_FILE", "cache.tsv"),
    timeout=30,
)

# %% [markdown]
# ## Classification: A simple example
#
# Let’s say we want to improve a prompt for labeling speaker responses. We’ll eventually run it with many different inputs, but plug in a concrete one for now:
#
# ```
# Instructions: Does Speaker 2's answer mean yes or no?
# Output labels: no, yes
# Input: Speaker 1: "You do this often?" Speaker 2: "It's my first time."
# Output:
# ```
#
# We have roughly four parts here: the instructions, the set of output labels, the input itself and a prefix. Let's convert this into a symbolic prompt program.

# %%
from sammo.components import Output, GenerateText, ForEach, Union, JoinStrings
from sammo.base import Template, VerbatimText

parts = list()

parts.append(VerbatimText("Instructions: Does Speaker 2's answer mean yes or no?", name="instructions"))
parts.append(VerbatimText("Output labels: no, yes", name="label_space"))
parts.append(Template("{{input}}", name="input"))
parts.append(VerbatimText("Output: ", name="prefix"))

spp = Output(GenerateText(JoinStrings(*parts, separator="\n")))
spp.plot_program()
# Out:
#             <iframe srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#
# &lt;head&gt;
#   &lt;style&gt;
#   body,
#   html {
#     margin: 0;
#     height: 100%;
#     width: 100%;
#   }
#
#   .split {
#     display: flex;
#     flex-direction: row;
#     height: 100%;
#     overflow: hidden;
#   }
#   .gutter {
#     background-color: #eee;
#     background-repeat: no-repeat;
#     background-position: 50%;
#   }
#
#   .gutter.gutter-horizontal {
#     background-image: url(&#x27;...&#x27;);
#     cursor: col-resize;
#   }
#   #info {
# 	overflow-y: auto;
#   }
#   #info div {
#     font-family: Helvetica, sans-serif;
#     font-weight: 600;
#     text-transform: uppercase;
#     background-color: #d6d8d9;
#     color: #616161;
#     font-size: 11px;
#     padding: 6px;
#   }
#   pre {
# 	white-space: pre-wrap;
# 	padding: 6px;
# 	background-color: #f9f9f9;
# 	margin: 0;
# 	font-size: 12px;
#   }
#   &lt;/style&gt;
#   &lt;meta charset=&quot;utf-8&quot; /&gt;
#   &lt;title&gt;Callgraph&lt;/title&gt;
#   &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/cytoscape/3.26.0/cytoscape.min.js&quot;&gt;&lt;/script&gt;
#   &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/split.js/1.6.0/split.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;div class=&quot;split&quot;&gt;
#     &lt;div id=&quot;info&quot;&gt;&lt;pre&gt;Click on node for details.&lt;/pre&gt;&lt;/div&gt;
#     &lt;div id=&quot;graph&quot;&gt;&lt;/div&gt;
#   &lt;/div&gt;
#   &lt;script&gt;
#   Split([&#x27;#info&#x27;, &#x27;#graph&#x27;], {
#     sizes: [20, 80],
#     minSize: [150, 0],
#     onDragEnd: resizeCyto
#   });
#   const DATA = {&quot;nodes&quot;: [{&quot;data&quot;: {&quot;id&quot;: 1768787440144, &quot;label&quot;: &quot;Output&quot;, &quot;priority&quot;: 0, &quot;details&quot;: {&quot;Parameters&quot;: &quot;- child: GenerateText\n- minibatch_size: 1\n- on_error: raise&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768804276816, &quot;label&quot;: &quot;GenerateText&quot;, &quot;priority&quot;: 1, &quot;details&quot;: {&quot;Parameters&quot;: &quot;- child: JoinStrings\n- name: None\n- system_prompt: None\n- history: None\n- seed: 0\n- randomness: 0\n- max_tokens: None\n- json_mode: False\n- on_error: empty_result&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768804410448, &quot;label&quot;: &quot;JoinStrings&quot;, &quot;priority&quot;: 2, &quot;details&quot;: {&quot;Parameters&quot;: &quot;- children: [\n  0 : VerbatimText(\n    template = \&quot;Instructions: Does Speaker 2&#x27;s answer mean yes or no?\&quot;,\n    name = &#x27;instructions&#x27;\n  ),\n  1 : VerbatimText(\n    template = &#x27;Output labels: no, yes&#x27;,\n    name = &#x27;label_space&#x27;\n  ),\n  2 : Template(\n    template_text = &#x27;{{input}}&#x27;,\n    name = &#x27;input&#x27;\n  ),\n  3 : VerbatimText(\n    template = &#x27;Output: &#x27;,\n    name = &#x27;prefix&#x27;\n  )\n]\n- separator: \n\n- name: None&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768786490000, &quot;label&quot;: &quot;VerbatimText&quot;, &quot;priority&quot;: 3, &quot;details&quot;: {&quot;Parameters&quot;: &quot;- template: Instructions: Does Speaker 2&#x27;s answer mean yes or no?\n- name: instructions&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768809797712, &quot;label&quot;: &quot;VerbatimText&quot;, &quot;priority&quot;: 4, &quot;details&quot;: {&quot;Parameters&quot;: &quot;- template: Output labels: no, yes\n- name: label_space&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768804404880, &quot;label&quot;: &quot;Template&quot;, &quot;priority&quot;: 5, &quot;details&quot;: {&quot;Parameters&quot;: &quot;- template_text: {{input}}\n- name: input&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768787436432, &quot;label&quot;: &quot;VerbatimText&quot;, &quot;priority&quot;: 6, &quot;details&quot;: {&quot;Parameters&quot;: &quot;- template: Output: \n- name: prefix&quot;}}}], &quot;edges&quot;: [{&quot;data&quot;: {&quot;target&quot;: 1768787440144, &quot;source&quot;: 1768804276816}}, {&quot;data&quot;: {&quot;target&quot;: 1768804276816, &quot;source&quot;: 1768804410448}}, {&quot;data&quot;: {&quot;target&quot;: 1768804410448, &quot;source&quot;: 1768786490000}}, {&quot;data&quot;: {&quot;target&quot;: 1768804410448, &quot;source&quot;: 1768809797712}}, {&quot;data&quot;: {&quot;target&quot;: 1768804410448, &quot;source&quot;: 1768804404880}}, {&quot;data&quot;: {&quot;target&quot;: 1768804410448, &quot;source&quot;: 1768787436432}}], &quot;node-color&quot;: &quot;white&quot;, &quot;node-border&quot;: 1};
#   var cy = cytoscape({
#     container: document.getElementById(&#x27;graph&#x27;),
#     style: cytoscape.stylesheet().selector(&#x27;node&#x27;).style({
#       &#x27;content&#x27;: &#x27;data(label)&#x27;,
# 	  &#x27;background-color&#x27;: DATA[&#x27;node-color&#x27;] || &#x27;Teal&#x27;,
# 	  &#x27;border-width&#x27;: DATA[&#x27;node-border&#x27;] || 0,
#     }).selector(&#x27;:selected&#x27;).style({&#x27;background-color&#x27;: &#x27;Turquoise&#x27;}).selector(&#x27;edge&#x27;).style({
#       &#x27;curve-style&#x27;: &#x27;bezier&#x27;,
#       &#x27;target-arrow-shape&#x27;: &#x27;triangle&#x27;,
#       &#x27;width&#x27;: 1,
#       &#x27;line-color&#x27;: &#x27;black&#x27;,
#       &#x27;target-arrow-color&#x27;: &#x27;black&#x27;
#     }),
#     elements: DATA,
#     wheelSensitivity: 0.3,
#     layout: {
#       name: &#x27;breadthfirst&#x27;,
#       directed: true,
#       depthSort: function(a, b){ return a.data(&#x27;priority&#x27;) - b.data(&#x27;priority&#x27;) }
#     }
#   });
#
#   function resizeCyto() {
#     cy.resize();
#     cy.fit();
#   }
#   window.addEventListener(&#x27;resize&#x27;, resizeCyto);
#   cy.on(&#x27;tap&#x27;, &#x27;node&#x27;, function(evt) {
#     const node = evt.target;
#     const details = node.data(&#x27;details&#x27;);
#     const info = document.getElementById(&#x27;info&#x27;);
#     info.innerHTML = &#x27;&#x27;;
#
#     if (!details) {
#         info.innerHTML = &quot;&lt;div&gt;Node has no metadata.&lt;/div&gt;&quot;;
#     } else if (typeof details === &#x27;object&#x27; &amp;&amp; !Array.isArray(details)) {
#         Object.entries(details).forEach(([key, value]) =&gt; {
#             info.innerHTML += `&lt;div&gt;${key}&lt;/div&gt;&lt;pre&gt;${value}&lt;/pre&gt;`;
#         });
#     } else {
#         info.innerHTML = `&lt;pre&gt;${details}&lt;/pre&gt;`;
#     }
#   });
#   &lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;
# " width="100%" height="300px"'
#             "allowfullscreen" style="border:1px solid #e0e0e0; box-sizing: border-box;">
#             </iframe>

# %% [markdown]
# `plot_program()` plots the structure of our SPP. An SPP is a graph where each node is an operator, or prompt **component** in SAMMO. You can click on each node to see what symbolic properties it has (and we'll edit those in a bit).
#
# A component receives as input the values of its children as well as any values that its parents passed through. Let's see this in action.

# %%
spp_result = spp.run(runner, ["Speaker 1: \"You do this often?\" Speaker 2: \"It's my first time.\""])

# %% [markdown]
# Okay, nice. Let's look at the trace.

# %%
spp_result.outputs[0].plot_call_trace()
# Out:
#             <iframe srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#
# &lt;head&gt;
#   &lt;style&gt;
#   body,
#   html {
#     margin: 0;
#     height: 100%;
#     width: 100%;
#   }
#
#   .split {
#     display: flex;
#     flex-direction: row;
#     height: 100%;
#     overflow: hidden;
#   }
#   .gutter {
#     background-color: #eee;
#     background-repeat: no-repeat;
#     background-position: 50%;
#   }
#
#   .gutter.gutter-horizontal {
#     background-image: url(&#x27;...&#x27;);
#     cursor: col-resize;
#   }
#   #info {
# 	overflow-y: auto;
#   }
#   #info div {
#     font-family: Helvetica, sans-serif;
#     font-weight: 600;
#     text-transform: uppercase;
#     background-color: #d6d8d9;
#     color: #616161;
#     font-size: 11px;
#     padding: 6px;
#   }
#   pre {
# 	white-space: pre-wrap;
# 	padding: 6px;
# 	background-color: #f9f9f9;
# 	margin: 0;
# 	font-size: 12px;
#   }
#   &lt;/style&gt;
#   &lt;meta charset=&quot;utf-8&quot; /&gt;
#   &lt;title&gt;Callgraph&lt;/title&gt;
#   &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/cytoscape/3.26.0/cytoscape.min.js&quot;&gt;&lt;/script&gt;
#   &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/split.js/1.6.0/split.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;div class=&quot;split&quot;&gt;
#     &lt;div id=&quot;info&quot;&gt;&lt;pre&gt;Click on node for details.&lt;/pre&gt;&lt;/div&gt;
#     &lt;div id=&quot;graph&quot;&gt;&lt;/div&gt;
#   &lt;/div&gt;
#   &lt;script&gt;
#   Split([&#x27;#info&#x27;, &#x27;#graph&#x27;], {
#     sizes: [20, 80],
#     minSize: [150, 0],
#     onDragEnd: resizeCyto
#   });
#   const DATA = {&quot;nodes&quot;: [{&quot;data&quot;: {&quot;id&quot;: 1768809444272, &quot;label&quot;: &quot;Output&quot;, &quot;priority&quot;: 1, &quot;details&quot;: {&quot;Output&quot;: &quot;no&quot;, &quot;Parameters&quot;: &quot;- child: GenerateText\n- minibatch_size: 1\n- on_error: raise&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768809526320, &quot;label&quot;: &quot;GenerateText&quot;, &quot;priority&quot;: 2, &quot;details&quot;: {&quot;Output&quot;: &quot;no&quot;, &quot;Parameters&quot;: &quot;- child: JoinStrings\n- name: None\n- system_prompt: None\n- history: None\n- seed: 0\n- randomness: 0\n- max_tokens: None\n- json_mode: False\n- on_error: empty_result&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768809441584, &quot;label&quot;: &quot;JoinStrings&quot;, &quot;priority&quot;: 3, &quot;details&quot;: {&quot;Output&quot;: &quot;Instructions: Does Speaker 2&#x27;s answer mean yes or no?\nOutput labels: no, yes\nSpeaker 1: \&quot;You do this often?\&quot; Speaker 2: \&quot;It&#x27;s my first time.\&quot;\nOutput: &quot;, &quot;Parameters&quot;: &quot;- children: [\n  0 : VerbatimText(\n    template = \&quot;Instructions: Does Speaker 2&#x27;s answer mean yes or no?\&quot;,\n    name = &#x27;instructions&#x27;\n  ),\n  1 : VerbatimText(\n    template = &#x27;Output labels: no, yes&#x27;,\n    name = &#x27;label_space&#x27;\n  ),\n  2 : Template(\n    template_text = &#x27;{{input}}&#x27;,\n    name = &#x27;input&#x27;\n  ),\n  3 : VerbatimText(\n    template = &#x27;Output: &#x27;,\n    name = &#x27;prefix&#x27;\n  )\n]\n- separator: \n\n- name: None&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768809440624, &quot;label&quot;: &quot;VerbatimText&quot;, &quot;priority&quot;: 4, &quot;details&quot;: {&quot;Output&quot;: &quot;Instructions: Does Speaker 2&#x27;s answer mean yes or no?&quot;, &quot;Parameters&quot;: &quot;- template: Instructions: Does Speaker 2&#x27;s answer mean yes or no?\n- name: instructions&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768809441872, &quot;label&quot;: &quot;VerbatimText&quot;, &quot;priority&quot;: 5, &quot;details&quot;: {&quot;Output&quot;: &quot;Output labels: no, yes&quot;, &quot;Parameters&quot;: &quot;- template: Output labels: no, yes\n- name: label_space&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768809440528, &quot;label&quot;: &quot;Template&quot;, &quot;priority&quot;: 6, &quot;details&quot;: {&quot;Output&quot;: &quot;Speaker 1: \&quot;You do this often?\&quot; Speaker 2: \&quot;It&#x27;s my first time.\&quot;&quot;, &quot;Parameters&quot;: &quot;- template_text: {{input}}\n- name: input&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768809441968, &quot;label&quot;: &quot;VerbatimText&quot;, &quot;priority&quot;: 7, &quot;details&quot;: {&quot;Output&quot;: &quot;Output: &quot;, &quot;Parameters&quot;: &quot;- template: Output: \n- name: prefix&quot;}}}], &quot;edges&quot;: [{&quot;data&quot;: {&quot;target&quot;: 1768809444272, &quot;source&quot;: 1768809526320}}, {&quot;data&quot;: {&quot;target&quot;: 1768809526320, &quot;source&quot;: 1768809441584}}, {&quot;data&quot;: {&quot;target&quot;: 1768809441584, &quot;source&quot;: 1768809440624}}, {&quot;data&quot;: {&quot;target&quot;: 1768809441584, &quot;source&quot;: 1768809441872}}, {&quot;data&quot;: {&quot;target&quot;: 1768809441584, &quot;source&quot;: 1768809440528}}, {&quot;data&quot;: {&quot;target&quot;: 1768809441584, &quot;source&quot;: 1768809441968}}]};
#   var cy = cytoscape({
#     container: document.getElementById(&#x27;graph&#x27;),
#     style: cytoscape.stylesheet().selector(&#x27;node&#x27;).style({
#       &#x27;content&#x27;: &#x27;data(label)&#x27;,
# 	  &#x27;background-color&#x27;: DATA[&#x27;node-color&#x27;] || &#x27;Teal&#x27;,
# 	  &#x27;border-width&#x27;: DATA[&#x27;node-border&#x27;] || 0,
#     }).selector(&#x27;:selected&#x27;).style({&#x27;background-color&#x27;: &#x27;Turquoise&#x27;}).selector(&#x27;edge&#x27;).style({
#       &#x27;curve-style&#x27;: &#x27;bezier&#x27;,
#       &#x27;target-arrow-shape&#x27;: &#x27;triangle&#x27;,
#       &#x27;width&#x27;: 1,
#       &#x27;line-color&#x27;: &#x27;black&#x27;,
#       &#x27;target-arrow-color&#x27;: &#x27;black&#x27;
#     }),
#     elements: DATA,
#     wheelSensitivity: 0.3,
#     layout: {
#       name: &#x27;breadthfirst&#x27;,
#       directed: true,
#       depthSort: function(a, b){ return a.data(&#x27;priority&#x27;) - b.data(&#x27;priority&#x27;) }
#     }
#   });
#
#   function resizeCyto() {
#     cy.resize();
#     cy.fit();
#   }
#   window.addEventListener(&#x27;resize&#x27;, resizeCyto);
#   cy.on(&#x27;tap&#x27;, &#x27;node&#x27;, function(evt) {
#     const node = evt.target;
#     const details = node.data(&#x27;details&#x27;);
#     const info = document.getElementById(&#x27;info&#x27;);
#     info.innerHTML = &#x27;&#x27;;
#
#     if (!details) {
#         info.innerHTML = &quot;&lt;div&gt;Node has no metadata.&lt;/div&gt;&quot;;
#     } else if (typeof details === &#x27;object&#x27; &amp;&amp; !Array.isArray(details)) {
#         Object.entries(details).forEach(([key, value]) =&gt; {
#             info.innerHTML += `&lt;div&gt;${key}&lt;/div&gt;&lt;pre&gt;${value}&lt;/pre&gt;`;
#         });
#     } else {
#         info.innerHTML = `&lt;pre&gt;${details}&lt;/pre&gt;`;
#     }
#   });
#   &lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;
# " width="100%" height="300px"'
#             "allowfullscreen" style="border:1px solid #e0e0e0; box-sizing: border-box;">
#             </iframe>

# %% [markdown]
# In contrast to the program graph, each node is now **filled** with concrete values of the computation. By clicking on each node, we can see what output it produced and pass up to its parent.

# %% [markdown]
# ## The power of symbolic prompt programs

# %% [markdown]
# What have we gained from this? A lot of flexibility to explore and optimize our prompt!
# Under the hood, SAMMO uses pyGlove to *symbolize* each class so that we can make arbitrary changes (this is also beyond static DSPy programs). pyGlove turns Python classes into manipulable, symbolic objects whose properties remain fully editable after instantiation.
#
# We can now query and modify prompt programs via a whole host of specifiers, similar to working with a DOM tree. Let’s say we’d like change the instructions. To do this, we can use the `.rebind()` function that pyGlove provides. Click on the first node to see the changes.

# %%
import pyglove as pg
spp.clone().rebind({'child.child.children[0].template': 'Does the response mean yes?'}).plot_program()
# Out:
#             <iframe srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#
# &lt;head&gt;
#   &lt;style&gt;
#   body,
#   html {
#     margin: 0;
#     height: 100%;
#     width: 100%;
#   }
#
#   .split {
#     display: flex;
#     flex-direction: row;
#     height: 100%;
#     overflow: hidden;
#   }
#   .gutter {
#     background-color: #eee;
#     background-repeat: no-repeat;
#     background-position: 50%;
#   }
#
#   .gutter.gutter-horizontal {
#     background-image: url(&#x27;...&#x27;);
#     cursor: col-resize;
#   }
#   #info {
# 	overflow-y: auto;
#   }
#   #info div {
#     font-family: Helvetica, sans-serif;
#     font-weight: 600;
#     text-transform: uppercase;
#     background-color: #d6d8d9;
#     color: #616161;
#     font-size: 11px;
#     padding: 6px;
#   }
#   pre {
# 	white-space: pre-wrap;
# 	padding: 6px;
# 	background-color: #f9f9f9;
# 	margin: 0;
# 	font-size: 12px;
#   }
#   &lt;/style&gt;
#   &lt;meta charset=&quot;utf-8&quot; /&gt;
#   &lt;title&gt;Callgraph&lt;/title&gt;
#   &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/cytoscape/3.26.0/cytoscape.min.js&quot;&gt;&lt;/script&gt;
#   &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/split.js/1.6.0/split.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;div class=&quot;split&quot;&gt;
#     &lt;div id=&quot;info&quot;&gt;&lt;pre&gt;Click on node for details.&lt;/pre&gt;&lt;/div&gt;
#     &lt;div id=&quot;graph&quot;&gt;&lt;/div&gt;
#   &lt;/div&gt;
#   &lt;script&gt;
#   Split([&#x27;#info&#x27;, &#x27;#graph&#x27;], {
#     sizes: [20, 80],
#     minSize: [150, 0],
#     onDragEnd: resizeCyto
#   });
#   const DATA = {&quot;nodes&quot;: [{&quot;data&quot;: {&quot;id&quot;: 1768804026448, &quot;label&quot;: &quot;Output&quot;, &quot;priority&quot;: 0, &quot;details&quot;: {&quot;Parameters&quot;: &quot;- child: GenerateText\n- minibatch_size: 1\n- on_error: raise&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768804040528, &quot;label&quot;: &quot;GenerateText&quot;, &quot;priority&quot;: 1, &quot;details&quot;: {&quot;Parameters&quot;: &quot;- child: JoinStrings\n- name: None\n- system_prompt: None\n- history: None\n- seed: 0\n- randomness: 0\n- max_tokens: None\n- json_mode: False\n- on_error: empty_result&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768794518096, &quot;label&quot;: &quot;JoinStrings&quot;, &quot;priority&quot;: 2, &quot;details&quot;: {&quot;Parameters&quot;: &quot;- children: [\n  0 : VerbatimText(\n    template = &#x27;Does the response mean yes?&#x27;,\n    name = &#x27;instructions&#x27;\n  ),\n  1 : VerbatimText(\n    template = &#x27;Output labels: no, yes&#x27;,\n    name = &#x27;label_space&#x27;\n  ),\n  2 : Template(\n    template_text = &#x27;{{input}}&#x27;,\n    name = &#x27;input&#x27;\n  ),\n  3 : VerbatimText(\n    template = &#x27;Output: &#x27;,\n    name = &#x27;prefix&#x27;\n  )\n]\n- separator: \n\n- name: None&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768804276560, &quot;label&quot;: &quot;VerbatimText&quot;, &quot;priority&quot;: 3, &quot;details&quot;: {&quot;Parameters&quot;: &quot;- template: Does the response mean yes?\n- name: instructions&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768804275024, &quot;label&quot;: &quot;VerbatimText&quot;, &quot;priority&quot;: 4, &quot;details&quot;: {&quot;Parameters&quot;: &quot;- template: Output labels: no, yes\n- name: label_space&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768804122320, &quot;label&quot;: &quot;Template&quot;, &quot;priority&quot;: 5, &quot;details&quot;: {&quot;Parameters&quot;: &quot;- template_text: {{input}}\n- name: input&quot;}}}, {&quot;data&quot;: {&quot;id&quot;: 1768804039312, &quot;label&quot;: &quot;VerbatimText&quot;, &quot;priority&quot;: 6, &quot;details&quot;: {&quot;Parameters&quot;: &quot;- template: Output: \n- name: prefix&quot;}}}], &quot;edges&quot;: [{&quot;data&quot;: {&quot;target&quot;: 1768804026448, &quot;source&quot;: 1768804040528}}, {&quot;data&quot;: {&quot;target&quot;: 1768804040528, &quot;source&quot;: 1768794518096}}, {&quot;data&quot;: {&quot;target&quot;: 1768794518096, &quot;source&quot;: 1768804276560}}, {&quot;data&quot;: {&quot;target&quot;: 1768794518096, &quot;source&quot;: 1768804275024}}, {&quot;data&quot;: {&quot;target&quot;: 1768794518096, &quot;source&quot;: 1768804122320}}, {&quot;data&quot;: {&quot;target&quot;: 1768794518096, &quot;source&quot;: 1768804039312}}], &quot;node-color&quot;: &quot;white&quot;, &quot;node-border&quot;: 1};
#   var cy = cytoscape({
#     container: document.getElementById(&#x27;graph&#x27;),
#     style: cytoscape.stylesheet().selector(&#x27;node&#x27;).style({
#       &#x27;content&#x27;: &#x27;data(label)&#x27;,
# 	  &#x27;background-color&#x27;: DATA[&#x27;node-color&#x27;] || &#x27;Teal&#x27;,
# 	  &#x27;border-width&#x27;: DATA[&#x27;node-border&#x27;] || 0,
#     }).selector(&#x27;:selected&#x27;).style({&#x27;background-color&#x27;: &#x27;Turquoise&#x27;}).selector(&#x27;edge&#x27;).style({
#       &#x27;curve-style&#x27;: &#x27;bezier&#x27;,
#       &#x27;target-arrow-shape&#x27;: &#x27;triangle&#x27;,
#       &#x27;width&#x27;: 1,
#       &#x27;line-color&#x27;: &#x27;black&#x27;,
#       &#x27;target-arrow-color&#x27;: &#x27;black&#x27;
#     }),
#     elements: DATA,
#     wheelSensitivity: 0.3,
#     layout: {
#       name: &#x27;breadthfirst&#x27;,
#       directed: true,
#       depthSort: function(a, b){ return a.data(&#x27;priority&#x27;) - b.data(&#x27;priority&#x27;) }
#     }
#   });
#
#   function resizeCyto() {
#     cy.resize();
#     cy.fit();
#   }
#   window.addEventListener(&#x27;resize&#x27;, resizeCyto);
#   cy.on(&#x27;tap&#x27;, &#x27;node&#x27;, function(evt) {
#     const node = evt.target;
#     const details = node.data(&#x27;details&#x27;);
#     const info = document.getElementById(&#x27;info&#x27;);
#     info.innerHTML = &#x27;&#x27;;
#
#     if (!details) {
#         info.innerHTML = &quot;&lt;div&gt;Node has no metadata.&lt;/div&gt;&quot;;
#     } else if (typeof details === &#x27;object&#x27; &amp;&amp; !Array.isArray(details)) {
#         Object.entries(details).forEach(([key, value]) =&gt; {
#             info.innerHTML += `&lt;div&gt;${key}&lt;/div&gt;&lt;pre&gt;${value}&lt;/pre&gt;`;
#         });
#     } else {
#         info.innerHTML = `&lt;pre&gt;${details}&lt;/pre&gt;`;
#     }
#   });
#   &lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;
# " width="100%" height="300px"'
#             "allowfullscreen" style="border:1px solid #e0e0e0; box-sizing: border-box;">
#             </iframe>

# %% [markdown]
# With this, you could automate a lot of the (semi)-manual tinkering you have to do during prompt prototyping. Making small edits such as paraphrasing would be just the start. Want to try out Chain-of-Thought reasoning? Add a paragraph that says “Let’s think step-by-step.” You can also explore
#
# * Going from single examples to batch annotation
# * Changing your retriever and ranking function in a RAG scenario
# * Re-ordering some of the paragraphs
# * Compressing certain parts of the instructions
# * Etc.
#
# ### Querying & manipulating SPPs
#
# There are several ways to manipulate and query SPPs. SAMMO provides a convinience function `.query()` that makes it easier to query by attributes, such as the name.

# %%
# Query by name
spp.query({"name": "instructions"})
# Out:
# VerbatimText(template="Instructions: Does Speaker 2's answer mean yes or no?", name='instructions')

# %%
# Query by name, but return attribute
spp.query({"name": "instructions", "_child": "template"})
# Out:
# "Instructions: Does Speaker 2's answer mean yes or no?"

# %% [markdown]
# By specifying the additional argument `return_path = True`, we get a full path with which we can call `rebind()`.

# %%
path, value = spp.query({"name": "instructions", "_child": "template"}, return_path = True)
spp.clone().rebind({path: 'Does the response mean yes?'})
path
# Out:
# 'child.child.children[0].template'
